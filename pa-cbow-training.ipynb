# %%
from types import SimpleNamespace
from collections import Counter
import os
import re
import pathlib
import array
import pickle
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
DATASET_VERSION = 'ca-100'
COMPETITION_ROOT = '../input/wordvectors'
DATASET_ROOT = f'../input/text-preprocessing/data/{DATASET_VERSION}'
WORKING_ROOT = f'data/{DATASET_VERSION}'
DATASET_PREFIX = 'ca.wiki'

# %%
params = SimpleNamespace(
    embedding_dim = 300, #100
    batch_size = 1000, # 1000
    epochs = 5,
    preprocessed = f'{DATASET_ROOT}/{DATASET_PREFIX}',
    working = f'{WORKING_ROOT}/{DATASET_PREFIX}',
    modelname = f'{WORKING_ROOT}/{DATASET_VERSION}.pt',
    train = True,
    weighting_scheme = 'trained_vector', # Options: 'uniform', 'fixed_scalar', 'trained_scalar', 'trained_vector'
)

# %%
class Vocabulary(object):
    def __init__(self, pad_token='<pad>', unk_token='<unk>', eos_token='<eos>'):
        self.token2idx = {}
        self.idx2token = []
        self.pad_token = pad_token
        self.unk_token = unk_token
        self.eos_token = eos_token
        if pad_token is not None:
            self.pad_index = self.add_token(pad_token)
        if unk_token is not None:
            self.unk_index = self.add_token(unk_token)
        if eos_token is not None:
            self.eos_index = self.add_token(eos_token)

    def add_token(self, token):
        if token not in self.token2idx:
            self.idx2token.append(token)
            self.token2idx[token] = len(self.idx2token) - 1
        return self.token2idx[token]

    def get_index(self, token):
        if isinstance(token, str):
            return self.token2idx.get(token, self.unk_index)
        else:
            return [self.token2idx.get(t, self.unk_index) for t in token]

    def get_token(self, index):
        return self.idx2token[index]

    def __len__(self):
        return len(self.idx2token)

    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self.__dict__, f)

    def load(self, filename):
        with open(filename, 'rb') as f:
            self.__dict__.update(pickle.load(f))

# %%
def batch_generator(idata, target, batch_size, shuffle=True):
    nsamples = len(idata)
    if shuffle:
        perm = np.random.permutation(nsamples)
    else:
        perm = range(nsamples)

    for i in range(0, nsamples, batch_size):
        batch_idx = perm[i:i+batch_size]
        if target is not None:
            yield idata[batch_idx], target[batch_idx]
        else:
            yield idata[batch_idx], None

# %% [markdown]
# CBOW model
# ----------
# You can add new parameters to the model in the *\_\_init\_\_()* method with *self.register_buffer()* (for parameters not to be trained):
#
#     self.register_buffer('position_weight', torch.tensor([1,2,3,3,2,1], dtype=torch.float32))
#
# or *nn.Parameter()* (for parameters to be trained)
#
#     self.position_weight = nn.Parameter(torch.tensor([1,2,3,3,2,1], dtype=torch.float32))
#
# In both cases, you can reference and use them in the *forward* method as
#
#     self.position_weight

# %%
class CBOW(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, weighting_scheme='uniform'):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)
        self.weighting_scheme = weighting_scheme
        self.context_size = 6  # 3 before, 3 after
        
        if weighting_scheme == 'fixed_scalar':
            self.position_weights = torch.tensor([1, 2, 3, 3, 2, 1], dtype=torch.float32)
            self.register_buffer('position_weights', self.position_weights)  # Fixed buffer name
            
        elif weighting_scheme == 'trained_scalar':
            self.position_weights = nn.Parameter(torch.ones(self.context_size))  # Initialize with ones
            
        elif weighting_scheme == 'trained_vector':
            self.position_weights = nn.Parameter(torch.ones(self.context_size, embedding_dim))  # Initialize with ones
            
    def forward(self, input):
        # input shape: (batch_size, context_size)
        batch_size = input.size(0)
        
        # Check input dimensions
        if input.size(1) != self.context_size:
            raise ValueError(f"Expected input context size of {self.context_size}, got {input.size(1)}")
            
        # Embedding lookup: (batch_size, context_size, embedding_dim)
        embedded = self.emb(input)
        
        if self.weighting_scheme == 'uniform':
            # Simple average
            context_vec = embedded.mean(dim=1)
            
        elif self.weighting_scheme == 'fixed_scalar':
            # Reshape weights for broadcasting: (1, context_size, 1)
            weights = self.position_weights.view(1, -1, 1)
            context_vec = (embedded * weights).sum(dim=1)
            context_vec = context_vec / weights.sum()  # Normalize
            
        elif self.weighting_scheme == 'trained_scalar':
            # Reshape weights for broadcasting: (1, context_size, 1)
            weights = self.position_weights.view(1, -1, 1)
            context_vec = (embedded * weights).sum(dim=1)
            context_vec = context_vec / weights.sum()  # Normalize
            
        elif self.weighting_scheme == 'trained_vector':
            # Reshape weights for broadcasting: (1, context_size, embedding_dim)
            weights = self.position_weights.view(1, self.context_size, -1)
            context_vec = (embedded * weights).sum(dim=1)
            context_vec = context_vec / weights.sum(dim=1)  # Normalize
            
        else:
            raise ValueError(f"Unknown weighting scheme: {self.weighting_scheme}")
        
        # Final prediction: (batch_size, num_embeddings)
        output = self.lin(context_vec)
        
        return output

class CBOW(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)
        self.context_size = 6
        # Initialize with slight preference for center words
        self.position_weights = nn.Parameter(torch.tensor([0.8, 0.9, 1.0, 1.0, 0.9, 0.8]))
        
    def forward(self, input):
        embedded = self.emb(input)
        weights = F.softmax(self.position_weights, dim=0).view(1, -1, 1)
        context_vec = (embedded * weights).sum(dim=1)
        return self.lin(context_vec)


class CBOW(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, context_size=3):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=True)  # Bias can help learning
        self.context_size = context_size  # Flexible context size
        self.dropout = nn.Dropout(0.2)  # Regularization
        
        # Learnable position-dependent weights (initialize closer words higher)
        init_weights = torch.tensor([1 / (abs(i - context_size) + 1) for i in range(2 * context_size)])
        self.position_weights = nn.Parameter(init_weights)

        # Layer normalization for stability
        self.norm = nn.LayerNorm(embedding_dim)

    def forward(self, input):
        embedded = self.emb(input)  # (batch_size, context_size*2, embedding_dim)
        
        # Normalize and apply softmax/sigmoid weighting
        weights = F.sigmoid(self.position_weights).view(1, -1, 1)  # Shape (1, context_size*2, 1)
        
        context_vec = (embedded * weights).sum(dim=1)  # Weighted sum
        context_vec = self.norm(context_vec)  # Normalize embeddings
        context_vec = self.dropout(context_vec)  # Regularization
        
        return self.lin(context_vec)  # Final output logits

# %% [markdown]
# We can visually show how this model works:
#
# <div style="text-align:center">
#     <img src="https://drive.google.com/uc?id=1INeftgKRCS0QWZu9InCDZ42a5fph3jQX" alt="drawing" width="800" height="800"/>
# </div>
#
# We train the model to learn matrices $\mathbf{E}$ and $\mathbf{W}$. Probabilities $P(w_t|w_{c-m},\cdots,w_{c+m})$ can be obtained by applying the softmax function to the output vector $\mathbf{z}$. However, our loss function [nn.CrossEntropyLoss()](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html) takes care of this.

# %%
def load_preprocessed_dataset(prefix):
    # Try loading precomputed vocabulary and preprocessed data files
    token_vocab = Vocabulary()
    token_vocab.load(f'{prefix}.vocab')
    data = []
    for part in ['train', 'valid', 'test']:
        with np.load(f'{prefix}.{part}.npz') as set_data:
            idata, target = set_data['idata'], set_data['target']
            data.append((idata, target))
            print(f'Number of samples ({part}): {len(target)}')
    print("Using precomputed vocabulary and data files")
    print(f'Vocabulary size: {len(token_vocab)}')
    return token_vocab, data

# %%
def train(model, criterion, optimizer, idata, target, batch_size, device, log=False):
    model.train()
    total_loss = 0
    ncorrect = 0
    ntokens = 0
    niterations = 0
    for X, y in batch_generator(idata, target, batch_size, shuffle=True):
        # Get input and target sequences from batch
        X = torch.tensor(X, dtype=torch.long, device=device)
        y = torch.tensor(y, dtype=torch.long, device=device)

        model.zero_grad()
        output = model(X)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        # Training statistics
        total_loss += loss.item()
        ncorrect += (torch.max(output, 1)[1] == y).sum().item()
        ntokens += y.numel()
        niterations += 1
        if niterations == 200 or niterations == 500 or niterations % 1000 == 0:
            print(f'Train: wpb={ntokens//niterations}, num_updates={niterations}, accuracy={100*ncorrect/ntokens:.1f}, loss={total_loss/ntokens:.2f}')

    total_loss = total_loss / ntokens
    accuracy = 100 * ncorrect / ntokens
    if log:
        print(f'Train: wpb={ntokens//niterations}, num_updates={niterations}, accuracy={accuracy:.1f}, loss={total_loss:.2f}')
    return accuracy, total_loss

# %%
def validate(model, criterion, idata, target, batch_size, device):
    model.eval()
    total_loss = 0
    ncorrect = 0
    ntokens = 0
    niterations = 0
    y_pred = []
    with torch.no_grad():
        for X, y in batch_generator(idata, target, batch_size, shuffle=False):
            # Get input and target sequences from batch
            X = torch.tensor(X, dtype=torch.long, device=device)
            output = model(X)
            if target is not None:
                y = torch.tensor(y, dtype=torch.long, device=device)
                loss = criterion(output, y)
                total_loss += loss.item()
                ncorrect += (torch.max(output, 1)[1] == y).sum().item()
                ntokens += y.numel()
                niterations += 1
            else:
                pred = torch.max(output, 1)[1].detach().to('cpu').numpy()
                y_pred.append(pred)

    if target is not None:
        total_loss = total_loss / ntokens
        accuracy = 100 * ncorrect / ntokens
        return accuracy, total_loss
    else:
        return np.concatenate(y_pred)

# %%
# Create working dir
pathlib.Path(WORKING_ROOT).mkdir(parents=True, exist_ok=True)

# %%
# Select device
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    print("WARNING: Training without GPU can be very slow!")

# %%
vocab, data = load_preprocessed_dataset(params.preprocessed)
# Out:
# Number of samples (train): 82284341
# Number of samples (valid): 164765
# Number of samples (test): 165837
# Using precomputed vocabulary and data files
# Vocabulary size: 100002

# %%
# 'El Periodico' validation dataset
valid_x_df = pd.read_csv(f'{COMPETITION_ROOT}/x_valid.csv')
tokens = valid_x_df.columns[1:]
valid_x = valid_x_df[tokens].apply(vocab.get_index).to_numpy(dtype='int32')
valid_y_df = pd.read_csv(f'{COMPETITION_ROOT}/y_valid.csv')
valid_y = valid_y_df['token'].apply(vocab.get_index).to_numpy(dtype='int32')

# %%
# 'El Periodico' test dataset
valid_x_df = pd.read_csv(f'{COMPETITION_ROOT}/x_test.csv')
test_x = valid_x_df[tokens].apply(vocab.get_index).to_numpy(dtype='int32')

# %%
model = CBOW(len(vocab), params.embedding_dim).to(device)
print(model)
for name, param in model.named_parameters():
    print(f'{name:20} {param.numel()} {list(param.shape)}')
print(f'TOTAL                {sum(p.numel() for p in model.parameters())}')
# Out:
# CBOW(
#   (emb): Embedding(100002, 300, padding_idx=0)
#   (lin): Linear(in_features=300, out_features=100002, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (norm): LayerNorm((300,), eps=1e-05, elementwise_affine=True)
# )
# position_weights     6 [6]
# emb.weight           30000600 [100002, 300]
# lin.weight           30000600 [100002, 300]
# lin.bias             100002 [100002]
# norm.weight          300 [300]
# norm.bias            300 [300]
# TOTAL                60101808

# %% [markdown]
# Note that $\textit{lin}$ layer transposes $\textit{lin.weight}$ before performing the multilplication.

# %% [markdown]
# The [nn.CrossEntropyLoss()](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html) criterion combines *nn.LogSoftmax()* and *nn.NLLLoss()* in one single class.

# %%
criterion = nn.CrossEntropyLoss(reduction='sum')

# %%
optimizer = torch.optim.Adam(model.parameters())

train_accuracy = []
wiki_accuracy = []
valid_accuracy = []
for epoch in range(params.epochs):
    acc, loss = train(model, criterion, optimizer, data[0][0], data[0][1], params.batch_size, device, log=True)
    train_accuracy.append(acc)
    print(f'| epoch {epoch:03d} | train accuracy={acc:.1f}%, train loss={loss:.2f}')
    acc, loss = validate(model, criterion, data[1][0], data[1][1], params.batch_size, device)
    wiki_accuracy.append(acc)
    print(f'| epoch {epoch:03d} | valid accuracy={acc:.1f}%, valid loss={loss:.2f} (wikipedia)')
    acc, loss = validate(model, criterion, valid_x, valid_y, params.batch_size, device)
    valid_accuracy.append(acc)
    print(f'| epoch {epoch:03d} | valid accuracy={acc:.1f}%, valid loss={loss:.2f} (El Periódico)')

# Save model
torch.save(model.state_dict(), params.modelname)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train: wpb=1000, num_updates=200, accuracy=7.2, loss=8.43
# Train: wpb=1000, num_updates=500, accuracy=10.5, loss=7.62
# Train: wpb=1000, num_updates=1000, accuracy=13.4, loss=7.04
# Train: wpb=1000, num_updates=2000, accuracy=16.7, loss=6.52
# Train: wpb=1000, num_updates=3000, accuracy=18.6, loss=6.24
# Train: wpb=1000, num_updates=4000, accuracy=19.9, loss=6.06
# Train: wpb=1000, num_updates=5000, accuracy=21.0, loss=5.92
# Train: wpb=1000, num_updates=6000, accuracy=21.8, loss=5.82
# Train: wpb=1000, num_updates=7000, accuracy=22.5, loss=5.73
# Train: wpb=1000, num_updates=8000, accuracy=23.1, loss=5.65
# Train: wpb=1000, num_updates=9000, accuracy=23.7, loss=5.59
# Train: wpb=1000, num_updates=10000, accuracy=24.1, loss=5.53
# Train: wpb=1000, num_updates=11000, accuracy=24.6, loss=5.48
# Train: wpb=1000, num_updates=12000, accuracy=24.9, loss=5.43
# Train: wpb=1000, num_updates=13000, accuracy=25.3, loss=5.39
# Train: wpb=1000, num_updates=14000, accuracy=25.6, loss=5.36
# Train: wpb=1000, num_updates=15000, accuracy=25.9, loss=5.32
# Train: wpb=1000, num_updates=16000, accuracy=26.1, loss=5.29
# Train: wpb=1000, num_updates=17000, accuracy=26.4, loss=5.26
# Train: wpb=1000, num_updates=18000, accuracy=26.6, loss=5.23
# Train: wpb=1000, num_updates=19000, accuracy=26.8, loss=5.21
# Train: wpb=1000, num_updates=20000, accuracy=27.0, loss=5.18
# Train: wpb=1000, num_updates=21000, accuracy=27.2, loss=5.16
# Train: wpb=1000, num_updates=22000, accuracy=27.4, loss=5.14
# Train: wpb=1000, num_updates=23000, accuracy=27.6, loss=5.12
# Train: wpb=1000, num_updates=24000, accuracy=27.7, loss=5.10
# Train: wpb=1000, num_updates=25000, accuracy=27.9, loss=5.08
# Train: wpb=1000, num_updates=26000, accuracy=28.0, loss=5.06
# Train: wpb=1000, num_updates=27000, accuracy=28.1, loss=5.05
# Train: wpb=1000, num_updates=28000, accuracy=28.3, loss=5.03
# Train: wpb=1000, num_updates=29000, accuracy=28.4, loss=5.01
# Train: wpb=1000, num_updates=30000, accuracy=28.5, loss=5.00
# Train: wpb=1000, num_updates=31000, accuracy=28.6, loss=4.99
# Train: wpb=1000, num_updates=32000, accuracy=28.7, loss=4.97
# Train: wpb=1000, num_updates=33000, accuracy=28.8, loss=4.96
# Train: wpb=1000, num_updates=34000, accuracy=28.9, loss=4.95
# Train: wpb=1000, num_updates=35000, accuracy=29.0, loss=4.94
# Train: wpb=1000, num_updates=36000, accuracy=29.1, loss=4.92
# Train: wpb=1000, num_updates=37000, accuracy=29.2, loss=4.91
# Train: wpb=1000, num_updates=38000, accuracy=29.3, loss=4.90
# Train: wpb=1000, num_updates=39000, accuracy=29.4, loss=4.89
# Train: wpb=1000, num_updates=40000, accuracy=29.4, loss=4.88
# Train: wpb=1000, num_updates=41000, accuracy=29.5, loss=4.87
# Train: wpb=1000, num_updates=42000, accuracy=29.6, loss=4.86
# Train: wpb=1000, num_updates=43000, accuracy=29.7, loss=4.85
# Train: wpb=1000, num_updates=44000, accuracy=29.7, loss=4.85
# Train: wpb=1000, num_updates=45000, accuracy=29.8, loss=4.84
# Train: wpb=1000, num_updates=46000, accuracy=29.9, loss=4.83
# Train: wpb=1000, num_updates=47000, accuracy=29.9, loss=4.82
# Train: wpb=1000, num_updates=48000, accuracy=30.0, loss=4.81
# Train: wpb=1000, num_updates=49000, accuracy=30.1, loss=4.81
# Train: wpb=1000, num_updates=50000, accuracy=30.1, loss=4.80
# Train: wpb=1000, num_updates=51000, accuracy=30.2, loss=4.79
# Train: wpb=1000, num_updates=52000, accuracy=30.2, loss=4.78
# Train: wpb=1000, num_updates=53000, accuracy=30.3, loss=4.78
# Train: wpb=1000, num_updates=54000, accuracy=30.3, loss=4.77
# Train: wpb=1000, num_updates=55000, accuracy=30.4, loss=4.76
# Train: wpb=1000, num_updates=56000, accuracy=30.4, loss=4.76
# Train: wpb=1000, num_updates=57000, accuracy=30.5, loss=4.75
# Train: wpb=1000, num_updates=58000, accuracy=30.5, loss=4.74
# Train: wpb=1000, num_updates=59000, accuracy=30.6, loss=4.74
# Train: wpb=1000, num_updates=60000, accuracy=30.6, loss=4.73
# Train: wpb=1000, num_updates=61000, accuracy=30.7, loss=4.73
# Train: wpb=1000, num_updates=62000, accuracy=30.7, loss=4.72
# Train: wpb=1000, num_updates=63000, accuracy=30.8, loss=4.71
# Train: wpb=1000, num_updates=64000, accuracy=30.8, loss=4.71
# Train: wpb=1000, num_updates=65000, accuracy=30.8, loss=4.70
# Train: wpb=1000, num_updates=66000, accuracy=30.9, loss=4.70
# Train: wpb=1000, num_updates=67000, accuracy=30.9, loss=4.69
# Train: wpb=1000, num_updates=68000, accuracy=31.0, loss=4.69
# Train: wpb=1000, num_updates=69000, accuracy=31.0, loss=4.68
# Train: wpb=1000, num_updates=70000, accuracy=31.0, loss=4.68
# Train: wpb=1000, num_updates=71000, accuracy=31.1, loss=4.67
# Train: wpb=1000, num_updates=72000, accuracy=31.1, loss=4.67
# Train: wpb=1000, num_updates=73000, accuracy=31.1, loss=4.67
# Train: wpb=1000, num_updates=74000, accuracy=31.2, loss=4.66
# Train: wpb=1000, num_updates=75000, accuracy=31.2, loss=4.66
# Train: wpb=1000, num_updates=76000, accuracy=31.3, loss=4.65
# Train: wpb=1000, num_updates=77000, accuracy=31.3, loss=4.65
# Train: wpb=1000, num_updates=78000, accuracy=31.3, loss=4.64
# Train: wpb=1000, num_updates=79000, accuracy=31.3, loss=4.64
# Train: wpb=1000, num_updates=80000, accuracy=31.4, loss=4.64
# Train: wpb=1000, num_updates=81000, accuracy=31.4, loss=4.63
# Train: wpb=1000, num_updates=82000, accuracy=31.4, loss=4.63
# Train: wpb=999, num_updates=82285, accuracy=31.4, loss=4.63
# | epoch 000 | train accuracy=31.4%, train loss=4.63
# | epoch 000 | valid accuracy=33.2%, valid loss=4.34 (wikipedia)
# | epoch 000 | valid accuracy=23.1%, valid loss=5.31 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=34.3, loss=4.23
# Train: wpb=1000, num_updates=500, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=1000, accuracy=34.3, loss=4.21
# Train: wpb=1000, num_updates=2000, accuracy=34.3, loss=4.21
# Train: wpb=1000, num_updates=3000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=4000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=5000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=6000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=7000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=8000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=9000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=10000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=11000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=12000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=13000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=14000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=15000, accuracy=34.2, loss=4.22
# Train: wpb=1000, num_updates=16000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=17000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=18000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=19000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=20000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=21000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=22000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=23000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=24000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=25000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=26000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=27000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=28000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=29000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=30000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=31000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=32000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=33000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=34000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=35000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=36000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=37000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=38000, accuracy=34.3, loss=4.22
# Train: wpb=1000, num_updates=39000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=40000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=41000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=42000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=43000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=44000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=45000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=46000, accuracy=34.4, loss=4.22
# Train: wpb=1000, num_updates=47000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=48000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=49000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=50000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=51000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=52000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=53000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=54000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=55000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=56000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=57000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=58000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=59000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=60000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=61000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=62000, accuracy=34.4, loss=4.21
# Train: wpb=1000, num_updates=63000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=64000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=65000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=66000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=67000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=68000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=69000, accuracy=34.5, loss=4.21
# Train: wpb=1000, num_updates=70000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=71000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=72000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=73000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=74000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=75000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=76000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=77000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=78000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=79000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=80000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=81000, accuracy=34.5, loss=4.20
# Train: wpb=1000, num_updates=82000, accuracy=34.5, loss=4.20
# Train: wpb=999, num_updates=82285, accuracy=34.5, loss=4.20
# | epoch 001 | train accuracy=34.5%, train loss=4.20
# | epoch 001 | valid accuracy=34.1%, valid loss=4.22 (wikipedia)
# | epoch 001 | valid accuracy=23.5%, valid loss=5.20 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=500, accuracy=35.1, loss=4.07
# Train: wpb=1000, num_updates=1000, accuracy=35.1, loss=4.07
# Train: wpb=1000, num_updates=2000, accuracy=35.1, loss=4.07
# Train: wpb=1000, num_updates=3000, accuracy=35.2, loss=4.07
# Train: wpb=1000, num_updates=4000, accuracy=35.2, loss=4.07
# Train: wpb=1000, num_updates=5000, accuracy=35.2, loss=4.08
# Train: wpb=1000, num_updates=6000, accuracy=35.2, loss=4.08
# Train: wpb=1000, num_updates=7000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=8000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=9000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=10000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=11000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=12000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=13000, accuracy=35.1, loss=4.08
# Train: wpb=1000, num_updates=14000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=15000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=16000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=17000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=18000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=19000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=20000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=21000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=22000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=23000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=24000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=25000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=26000, accuracy=35.1, loss=4.09
# Train: wpb=1000, num_updates=27000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=28000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=29000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=30000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=31000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=32000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=33000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=34000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=35000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=36000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=37000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=38000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=39000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=40000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=41000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=42000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=43000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=44000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=45000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=46000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=47000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=48000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=49000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=50000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=51000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=52000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=53000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=54000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=55000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=56000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=57000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=58000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=59000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=60000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=61000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=62000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=63000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=64000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=65000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=66000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=67000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=68000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=69000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=70000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=71000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=72000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=73000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=74000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=75000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=76000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=77000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=78000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=79000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=80000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=81000, accuracy=35.1, loss=4.10
# Train: wpb=1000, num_updates=82000, accuracy=35.1, loss=4.10
# Train: wpb=999, num_updates=82285, accuracy=35.1, loss=4.10
# | epoch 002 | train accuracy=35.1%, train loss=4.10
# | epoch 002 | valid accuracy=34.3%, valid loss=4.18 (wikipedia)
# | epoch 002 | valid accuracy=23.9%, valid loss=5.18 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=35.5, loss=4.00
# Train: wpb=1000, num_updates=500, accuracy=35.5, loss=4.00
# Train: wpb=1000, num_updates=1000, accuracy=35.4, loss=4.01
# Train: wpb=1000, num_updates=2000, accuracy=35.5, loss=4.01
# Train: wpb=1000, num_updates=3000, accuracy=35.5, loss=4.01
# Train: wpb=1000, num_updates=4000, accuracy=35.5, loss=4.01
# Train: wpb=1000, num_updates=5000, accuracy=35.5, loss=4.02
# Train: wpb=1000, num_updates=6000, accuracy=35.5, loss=4.02
# Train: wpb=1000, num_updates=7000, accuracy=35.5, loss=4.02
# Train: wpb=1000, num_updates=8000, accuracy=35.5, loss=4.02
# Train: wpb=1000, num_updates=9000, accuracy=35.5, loss=4.02
# Train: wpb=1000, num_updates=10000, accuracy=35.5, loss=4.02
# Train: wpb=1000, num_updates=11000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=12000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=13000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=14000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=15000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=16000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=17000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=18000, accuracy=35.5, loss=4.03
# Train: wpb=1000, num_updates=19000, accuracy=35.4, loss=4.03
# Train: wpb=1000, num_updates=20000, accuracy=35.4, loss=4.03
# Train: wpb=1000, num_updates=21000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=22000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=23000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=24000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=25000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=26000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=27000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=28000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=29000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=30000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=31000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=32000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=33000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=34000, accuracy=35.4, loss=4.04
# Train: wpb=1000, num_updates=35000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=36000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=37000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=38000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=39000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=40000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=41000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=42000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=43000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=44000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=45000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=46000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=47000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=48000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=49000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=50000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=51000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=52000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=53000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=54000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=55000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=56000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=57000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=58000, accuracy=35.4, loss=4.05
# Train: wpb=1000, num_updates=59000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=60000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=61000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=62000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=63000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=64000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=65000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=66000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=67000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=68000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=69000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=70000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=71000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=72000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=73000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=74000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=75000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=76000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=77000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=78000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=79000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=80000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=81000, accuracy=35.4, loss=4.06
# Train: wpb=1000, num_updates=82000, accuracy=35.4, loss=4.06
# Train: wpb=999, num_updates=82285, accuracy=35.4, loss=4.06
# | epoch 003 | train accuracy=35.4%, train loss=4.06
# | epoch 003 | valid accuracy=34.5%, valid loss=4.15 (wikipedia)
# | epoch 003 | valid accuracy=23.9%, valid loss=5.16 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=35.8, loss=3.97
# Train: wpb=1000, num_updates=500, accuracy=35.8, loss=3.97
# Train: wpb=1000, num_updates=1000, accuracy=35.7, loss=3.97
# Train: wpb=1000, num_updates=2000, accuracy=35.7, loss=3.97
# Train: wpb=1000, num_updates=3000, accuracy=35.7, loss=3.98
# Train: wpb=1000, num_updates=4000, accuracy=35.7, loss=3.98
# Train: wpb=1000, num_updates=5000, accuracy=35.7, loss=3.98
# Train: wpb=1000, num_updates=6000, accuracy=35.7, loss=3.98
# Train: wpb=1000, num_updates=7000, accuracy=35.7, loss=3.99
# Train: wpb=1000, num_updates=8000, accuracy=35.7, loss=3.99
# Train: wpb=1000, num_updates=9000, accuracy=35.7, loss=3.99
# Train: wpb=1000, num_updates=10000, accuracy=35.7, loss=3.99
# Train: wpb=1000, num_updates=11000, accuracy=35.7, loss=3.99
# Train: wpb=1000, num_updates=12000, accuracy=35.7, loss=4.00
# Train: wpb=1000, num_updates=13000, accuracy=35.7, loss=4.00
# Train: wpb=1000, num_updates=14000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=15000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=16000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=17000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=18000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=19000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=20000, accuracy=35.6, loss=4.00
# Train: wpb=1000, num_updates=21000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=22000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=23000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=24000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=25000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=26000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=27000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=28000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=29000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=30000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=31000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=32000, accuracy=35.6, loss=4.01
# Train: wpb=1000, num_updates=33000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=34000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=35000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=36000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=37000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=38000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=39000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=40000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=41000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=42000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=43000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=44000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=45000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=46000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=47000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=48000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=49000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=50000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=51000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=52000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=53000, accuracy=35.6, loss=4.02
# Train: wpb=1000, num_updates=54000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=55000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=56000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=57000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=58000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=59000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=60000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=61000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=62000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=63000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=64000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=65000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=66000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=67000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=68000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=69000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=70000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=71000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=72000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=73000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=74000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=75000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=76000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=77000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=78000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=79000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=80000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=81000, accuracy=35.6, loss=4.03
# Train: wpb=1000, num_updates=82000, accuracy=35.6, loss=4.03
# Train: wpb=999, num_updates=82285, accuracy=35.6, loss=4.03
# | epoch 004 | train accuracy=35.6%, train loss=4.03
# | epoch 004 | valid accuracy=34.6%, valid loss=4.14 (wikipedia)
# | epoch 004 | valid accuracy=23.9%, valid loss=5.15 (El Periódico)

# %%
# Test prediction
y_pred = validate(model, None, test_x, None, params.batch_size, device)
y_token = [vocab.idx2token[index] for index in y_pred]

# %%
submission = pd.DataFrame({'id':valid_x_df['id'], 'token': y_token}, columns=['id', 'token'])
print(submission.head())
submission.to_csv('submission.csv', index=False)
# Out:
#    id  token
# 0   0      l
# 1   1      s
# 2   2  haver
# 3   3      s
# 4   4     un
